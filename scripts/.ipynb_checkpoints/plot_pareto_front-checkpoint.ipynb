# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
def pareto_frontier(Xs, Ys, maxX = False, maxY = False):
# Sort the list in either ascending or descending order of X
    myList = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxX)
# Start the Pareto frontier with the first value in the sorted list
    p_front = [myList[0]]    
# Loop through the sorted list
    for pair in myList[1:]:
        if maxY: 
            if pair[1] >= p_front[-1][1]: # Look for higher values of Y…
                p_front.append(pair) # … and add them to the Pareto frontier
        else:
            if pair[1] <= p_front[-1][1]: # Look for lower values of Y…
                p_front.append(pair) # … and add them to the Pareto frontier
# Turn resulting pairs back into a list of Xs and Ys
    p_frontX = [pair[0] for pair in p_front]
    p_frontY = [pair[1] for pair in p_front]
    return p_frontX, p_frontY

# %%
# open log file
#with open("../outputs/saved/cnv_6_hls4ml.csv","r") as f:
with open("../outputs/saved/cnv_6_fpgaconvnet.csv","r") as f:
    reader = csv.reader(f, delimiter=',')
    log = [ [ int(float(row[0])), int(row[1]), int(row[2]), int(row[3]), int(row[4]), True if row[5] == "True" else False ] for row in reader ] 
    
# get latency and resources
latency = [ row[0] for row in log ]
resource = [ 0.25*row[1]/2160 + 0.25*row[2]/2760 + 0.25*row[3]/663360 + 0.25*row[4]/331680 for row in log]

latency_chosen = []
resource_chosen = []
for row in log:
    if row[-1]:
        latency_chosen += [row[0]]
        resource_chosen += [0.25*row[1]/2160 + 0.25*row[2]/2760 + 0.25*row[3]/663360 + 0.25*row[4]/331680]

# %%
# plot pareto-optimal front
pareto_front = pareto_frontier(resource, latency)
plt.scatter(resource, latency, marker="x", alpha=0.5)
plt.plot(*pareto_front, color="r")
plt.scatter(resource_chosen[-1], latency_chosen[-1], color="r", marker="x")
plt.yscale("log")
plt.grid()
plt.ylabel("Latency (cycles)")
plt.xlabel("Resource Utilisation (%)")
plt.autoscale(enable=True, axis='x', tight=True)
plt.show()

# %%
plt.plot(np.arange(len(latency_chosen)), latency_chosen)
plt.yscale("log")
plt.ylabel("Latency (cycles)")
plt.xlabel("Iterations")
plt.grid()
plt.autoscale(enable=True, axis='x', tight=True)
plt.show()

# %%
# scatter plot of all of the designs
## fpgaConvNet
pred_latency = np.array([64, 784, 8000, 200704])
actual_latency = np.array([143, 814, 8046, 200749])
pred_rsc = np.array([38.67, 57.62, 54.8, 52.49])
actual_rsc = np.array([27.77, 83.09, 46.83, 66.94])

markers=["x", "o", "^", "d"]

plt.scatter(pred_rsc, pred_latency, color=["r", "b","m","y"], marker="x", label="fpgaConvNet")
plt.scatter(actual_rsc, actual_latency, color=["r", "b","m","y"], marker="x")
plt.quiver(pred_rsc, pred_latency, actual_rsc-pred_rsc, actual_latency-pred_latency, 
           angles='xy', scale_units='xy', scale=1, linewidth=0.5, alpha=0.25)

## HLS4ML
pred_latency = np.array([32, 392])
actual_latency = np.array([42, 1164])
pred_rsc = np.array([39.98, 34.24])
actual_rsc = np.array([42.61, 90.64])

plt.scatter(pred_rsc, pred_latency, color=["r", "b"], marker="o", label="HLS4ML")
plt.scatter(actual_rsc, actual_latency, color=["r", "b"], marker="o")
plt.quiver(pred_rsc, pred_latency, actual_rsc-pred_rsc, actual_latency-pred_latency, 
           angles='xy', scale_units='xy', scale=1, linewidth=0.5, alpha=0.25)


## FINN
pred_latency = np.array([32, 392])
actual_latency = np.array([42, 403])
pred_rsc = np.array([67.46, 30.50])
actual_rsc = np.array([66.63, 37.11])

plt.scatter(pred_rsc, pred_latency, color=["r", "b"], marker="^", label="FINN")
plt.scatter(actual_rsc, actual_latency, color=["r", "b"], marker="^")
plt.quiver(pred_rsc, pred_latency, actual_rsc-pred_rsc, actual_latency-pred_latency, 
           angles='xy', scale_units='xy', scale=1, linewidth=0.5, alpha=0.25)

plt.grid()
plt.ylabel("Latency (cycles)")
plt.xlabel("Resource Utilisation (%)")
plt.yscale("log")
plt.legend()
plt.show()
